# %% [markdown]
# ### Table of Contents
#     01. Import libraries
#     02. Import data sets
#     03. Data wrangling
#         a. 2015 dataset
#         b. 2016 dataset
#         c. 2017 dataset
#         d. 2018 dataset
#         e. 2019 dataset
#     04. Data merging
#         a. Additional data wrangling
#     05. Data consistency checks
#         a. Check for missing data
#         b. Check for duplicates
#         c. Check for mixed-type data
#     06. Data exporting

# %% [markdown]
# # 01. Import libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
# Create a path for easier importing of files
path = r'C:\Users\blim9\Desktop\Career Foundry\Data Immersion\Achievement 6\World Happiness Report'

# %% [markdown]
# # 02. Import data sets

# %%
# Import five data sets for the years 2015 - 2019
df_2015 = pd.read_csv(os.path.join (path, '02. Data', 'Original Data', '2015.csv'), index_col = False)
df_2016 = pd.read_csv(os.path.join (path, '02. Data', 'Original Data', '2016.csv'), index_col = False)
df_2017 = pd.read_csv(os.path.join (path, '02. Data', 'Original Data', '2017.csv'), index_col = False)
df_2018 = pd.read_csv(os.path.join (path, '02. Data', 'Original Data', '2018.csv'), index_col = False)
df_2019 = pd.read_csv(os.path.join (path, '02. Data', 'Original Data', '2019.csv'), index_col = False)

# %% [markdown]
# ### After familiarizing myself with all five datasets, I noticed that there are inconsistencies with the column names.
#
# ### We will first begin by wrangling the data to create consistent names in which we can easily merge into one integrated dataset. I will be using the 2015 dataset as a benchmark for the structure and naming convention.

# %% [markdown]
# # 03. Data wrangling

# %% [markdown]
# ## 2015 - World Happiness Report

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
# Drop the standard error column as it is irrelevant for our project
df_2015 = df_2015.drop(columns = ['Standard Error'])

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %%
# Rename the Family, Freedom, and Generosity columns for further clarification
df_2015 = df_2015.rename(columns = {'Family' : 'Family (Social Support)', 'Freedom' : 'Freedom (Life Choices)', 'Generosity' : 'Generosity (Donations to Charity)'})

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# 4                   0.90563                 0.63297
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.41978                            0.29678
# 1                        0.14145                            0.43630
# 2                        0.48357                            0.34139
# 3                        0.36503                            0.34699
# 4                        0.32957                            0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
# Create a new column called Year to specify the year
df_2015['Year'] = 2015

# %%
df_2015 = df_2015.reindex(columns = ['Country', 'Region', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
               'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',\
               'Dystopia Residual'])

# %%
df_2015.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# 4                   0.90563                 0.63297
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.41978                            0.29678
# 1                        0.14145                            0.43630
# 2                        0.48357                            0.34139
# 3                        0.36503                            0.34699
# 4                        0.32957                            0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
# Check for any outliers or irregular values within the descriptive statistics
df_2015.describe()
# Out:
#          Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   158.0      158.000000       158.000000                158.000000
# mean   2015.0       79.493671         5.375734                  0.846137
# std       0.0       45.754363         1.145010                  0.403121
# min    2015.0        1.000000         2.839000                  0.000000
# 25%    2015.0       40.250000         4.526000                  0.545808
# 50%    2015.0       79.500000         5.232500                  0.910245
# 75%    2015.0      118.750000         6.243750                  1.158448
# max    2015.0      158.000000         7.587000                  1.690420
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               158.000000                158.000000
# mean                  0.991046                  0.630259
# std                   0.272369                  0.247078
# min                   0.000000                  0.000000
# 25%                   0.856823                  0.439185
# 50%                   1.029510                  0.696705
# 75%                   1.214405                  0.811013
# max                   1.402230                  1.025250
#
#        Freedom (Life Choices)  Trust (Government Corruption)  \
# count              158.000000                     158.000000
# mean                 0.428615                       0.143422
# std                  0.150693                       0.120034
# min                  0.000000                       0.000000
# 25%                  0.328330                       0.061675
# 50%                  0.435515                       0.107220
# 75%                  0.549092                       0.180255
# max                  0.669730                       0.551910
#
#        Generosity (Donations to Charity)  Dystopia Residual
# count                         158.000000         158.000000
# mean                            0.237296           2.098977
# std                             0.126685           0.553550
# min                             0.000000           0.328580
# 25%                             0.150553           1.759410
# 50%                             0.216130           2.095415
# 75%                             0.309883           2.462415
# max                             0.795880           3.602140

# %% [markdown]
# ## 2016 - World Happiness Report

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
# Drop the Lower Confidence and Upper Confidence Interval columns as they are irrelevant for our project
df_2016 = df_2016.drop(columns = ['Lower Confidence Interval', 'Upper Confidence Interval'])

# %%
# Check that the columns were dropped
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
# Rename the Family, Freedom, and Generosity columns for further clarification
df_2016 = df_2016.rename(columns = {'Family' : 'Family (Social Support)', 'Freedom' : 'Freedom (Life Choices)', 'Generosity' : 'Generosity (Donations to Charity)'})

# %%
# Check that the columns were renamed
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
# 2                   1.42666                  1.18326
# 3                   1.57744                  1.12690
# 4                   1.40598                  1.13464
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.79504                 0.57941
# 1                   0.86303                 0.58557
# 2                   0.86733                 0.56624
# 3                   0.79579                 0.59609
# 4                   0.81091                 0.57104
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.44453                            0.36171
# 1                        0.41203                            0.28083
# 2                        0.14975                            0.47678
# 3                        0.35776                            0.37895
# 4                        0.41004                            0.25492
#
#    Dystopia Residual
# 0            2.73939
# 1            2.69463
# 2            2.83137
# 3            2.66465
# 4            2.82596

# %%
# Create a new column called Year to specify the year
df_2016['Year'] = 2016

# %%
df_2016 = df_2016.reindex(columns = ['Country', 'Region', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
               'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',\
               'Dystopia Residual'])

# %%
df_2016.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe  2016               1            7.526
# 1  Switzerland  Western Europe  2016               2            7.509
# 2      Iceland  Western Europe  2016               3            7.501
# 3       Norway  Western Europe  2016               4            7.498
# 4      Finland  Western Europe  2016               5            7.413
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.44178                  1.16374
# 1                   1.52733                  1.14524
# 2                   1.42666                  1.18326
# 3                   1.57744                  1.12690
# 4                   1.40598                  1.13464
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.79504                 0.57941
# 1                   0.86303                 0.58557
# 2                   0.86733                 0.56624
# 3                   0.79579                 0.59609
# 4                   0.81091                 0.57104
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.44453                            0.36171
# 1                        0.41203                            0.28083
# 2                        0.14975                            0.47678
# 3                        0.35776                            0.37895
# 4                        0.41004                            0.25492
#
#    Dystopia Residual
# 0            2.73939
# 1            2.69463
# 2            2.83137
# 3            2.66465
# 4            2.82596

# %%
# Check for any outliers or irregular values within the descriptive statistics
df_2016.describe()
# Out:
#          Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   157.0      157.000000       157.000000                157.000000
# mean   2016.0       78.980892         5.382185                  0.953880
# std       0.0       45.466030         1.141674                  0.412595
# min    2016.0        1.000000         2.905000                  0.000000
# 25%    2016.0       40.000000         4.404000                  0.670240
# 50%    2016.0       79.000000         5.314000                  1.027800
# 75%    2016.0      118.000000         6.269000                  1.279640
# max    2016.0      157.000000         7.526000                  1.824270
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               157.000000                157.000000
# mean                  0.793621                  0.557619
# std                   0.266706                  0.229349
# min                   0.000000                  0.000000
# 25%                   0.641840                  0.382910
# 50%                   0.841420                  0.596590
# 75%                   1.021520                  0.729930
# max                   1.183260                  0.952770
#
#        Freedom (Life Choices)  Trust (Government Corruption)  \
# count              157.000000                     157.000000
# mean                 0.370994                       0.137624
# std                  0.145507                       0.111038
# min                  0.000000                       0.000000
# 25%                  0.257480                       0.061260
# 50%                  0.397470                       0.105470
# 75%                  0.484530                       0.175540
# max                  0.608480                       0.505210
#
#        Generosity (Donations to Charity)  Dystopia Residual
# count                         157.000000         157.000000
# mean                            0.242635           2.325807
# std                             0.133756           0.542220
# min                             0.000000           0.817890
# 25%                             0.154570           2.031710
# 50%                             0.222450           2.290740
# 75%                             0.311850           2.664650
# max                             0.819710           3.837720

# %% [markdown]
# ## 2017 - World Happiness Report

# %%
df_2017.head()
# Out:
#        Country          Region  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0       Norway  Western Europe               1            7.537      7.594445
# 1      Denmark  Western Europe               2            7.522      7.581728
# 2      Iceland  Western Europe               3            7.504      7.622030
# 3  Switzerland  Western Europe               4            7.494      7.561772
# 4      Finland  Western Europe               5            7.469      7.527542
#
#    Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# 0     7.479556                  1.616463  1.533524                  0.796667
# 1     7.462272                  1.482383  1.551122                  0.792566
# 2     7.385970                  1.480633  1.610574                  0.833552
# 3     7.426227                  1.564980  1.516912                  0.858131
# 4     7.410458                  1.443572  1.540247                  0.809158
#
#     Freedom  Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0  0.635423    0.362012                       0.315964           2.277027
# 1  0.626007    0.355280                       0.400770           2.313707
# 2  0.627163    0.475540                       0.153527           2.322715
# 3  0.620071    0.290549                       0.367007           2.276716
# 4  0.617951    0.245483                       0.382612           2.430182

# %%
# Drop the Whisker high and Whisker low columns as they are irrelevant for our project
df_2017 = df_2017.drop(columns = ['Whisker.high', 'Whisker.low'])

# %%
# Check that the columns were dropped
df_2017.head()
# Out:
#        Country          Region  Happiness.Rank  Happiness.Score  \
# 0       Norway  Western Europe               1            7.537
# 1      Denmark  Western Europe               2            7.522
# 2      Iceland  Western Europe               3            7.504
# 3  Switzerland  Western Europe               4            7.494
# 4      Finland  Western Europe               5            7.469
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
# Rename various columns to conform to the previous data set's naming conventions
df_2017 = df_2017.rename(columns = {'Happiness.Rank': 'Happiness Rank', 'Happiness.Score': 'Happiness Score', 'Economy..GDP.per.Capita.':
                                   'Economy (GDP per Capita)', 'Family': 'Family (Social Support)', 'Health..Life.Expectancy.':
                                   'Health (Life Expectancy)', 'Freedom': 'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)', 
                                   'Trust..Government.Corruption.': 'Trust (Government Corruption)', 'Dystopia.Residual': 
                                   'Dystopia Residual'})

# %%
# Check that the columns were renamed
df_2017.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0       Norway  Western Europe               1            7.537
# 1      Denmark  Western Europe               2            7.522
# 2      Iceland  Western Europe               3            7.504
# 3  Switzerland  Western Europe               4            7.494
# 4      Finland  Western Europe               5            7.469
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.616463                 1.533524
# 1                  1.482383                 1.551122
# 2                  1.480633                 1.610574
# 3                  1.564980                 1.516912
# 4                  1.443572                 1.540247
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                  0.796667                0.635423
# 1                  0.792566                0.626007
# 2                  0.833552                0.627163
# 3                  0.858131                0.620071
# 4                  0.809158                0.617951
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)  \
# 0                           0.362012                       0.315964
# 1                           0.355280                       0.400770
# 2                           0.475540                       0.153527
# 3                           0.290549                       0.367007
# 4                           0.245483                       0.382612
#
#    Dystopia Residual
# 0           2.277027
# 1           2.313707
# 2           2.322715
# 3           2.276716
# 4           2.430182

# %%
# Create a new column called Year to specify the year
df_2017['Year'] = 2017

# %%
# Reorder the order of the columns so it's consistent with the previous datasets
df_2017 = df_2017.reindex(columns = ['Country', 'Region', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
                                    'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',
                                    'Dystopia Residual'])

# %%
# Check that the columns were reordered
df_2017.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0       Norway  Western Europe  2017               1            7.537
# 1      Denmark  Western Europe  2017               2            7.522
# 2      Iceland  Western Europe  2017               3            7.504
# 3  Switzerland  Western Europe  2017               4            7.494
# 4      Finland  Western Europe  2017               5            7.469
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                  1.616463                 1.533524
# 1                  1.482383                 1.551122
# 2                  1.480633                 1.610574
# 3                  1.564980                 1.516912
# 4                  1.443572                 1.540247
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                  0.796667                0.635423
# 1                  0.792566                0.626007
# 2                  0.833552                0.627163
# 3                  0.858131                0.620071
# 4                  0.809158                0.617951
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                       0.315964                           0.362012
# 1                       0.400770                           0.355280
# 2                       0.153527                           0.475540
# 3                       0.367007                           0.290549
# 4                       0.382612                           0.245483
#
#    Dystopia Residual
# 0           2.277027
# 1           2.313707
# 2           2.322715
# 3           2.276716
# 4           2.430182

# %%
# Check for any outliers or irregular values within the descriptive statistics
df_2017.describe()
# Out:
#          Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   155.0      155.000000       155.000000                155.000000
# mean   2017.0       78.000000         5.354019                  0.984718
# std       0.0       44.888751         1.131230                  0.420793
# min    2017.0        1.000000         2.693000                  0.000000
# 25%    2017.0       39.500000         4.505500                  0.663371
# 50%    2017.0       78.000000         5.279000                  1.064578
# 75%    2017.0      116.500000         6.101500                  1.318027
# max    2017.0      155.000000         7.537000                  1.870766
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               155.000000                155.000000
# mean                  1.188898                  0.551341
# std                   0.287263                  0.237073
# min                   0.000000                  0.000000
# 25%                   1.042635                  0.369866
# 50%                   1.253918                  0.606042
# 75%                   1.414316                  0.723008
# max                   1.610574                  0.949492
#
#        Freedom (Life Choices)  Trust (Government Corruption)  \
# count              155.000000                     155.000000
# mean                 0.408786                       0.123120
# std                  0.149997                       0.101661
# min                  0.000000                       0.000000
# 25%                  0.303677                       0.057271
# 50%                  0.437454                       0.089848
# 75%                  0.516561                       0.153296
# max                  0.658249                       0.464308
#
#        Generosity (Donations to Charity)  Dystopia Residual
# count                         155.000000         155.000000
# mean                            0.246883           1.850238
# std                             0.134780           0.500028
# min                             0.000000           0.377914
# 25%                             0.154106           1.591291
# 50%                             0.231538           1.832910
# 75%                             0.323762           2.144654
# max                             0.838075           3.117485

# %% [markdown]
# ## 2018 - World Happiness Report

# %%
df_2018.head()
# Out:
#    Overall rank Country or region          Region  Score  GDP per capita  \
# 0             1           Finland  Western Europe  7.632           1.305
# 1             2            Norway  Western Europe  7.594           1.456
# 2             3           Denmark  Western Europe  7.555           1.351
# 3             4           Iceland  Western Europe  7.495           1.343
# 4             5       Switzerland  Western Europe  7.487           1.420
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.592                    0.874                         0.681
# 1           1.582                    0.861                         0.686
# 2           1.590                    0.868                         0.683
# 3           1.644                    0.914                         0.677
# 4           1.549                    0.927                         0.660
#
#    Generosity  Perceptions of corruption
# 0       0.202                      0.393
# 1       0.286                      0.340
# 2       0.284                      0.408
# 3       0.353                      0.138
# 4       0.256                      0.357

# %%
# Rename various columns to conform to the previous data set's naming conventions
df_2018 = df_2018.rename(columns = {'Overall rank': 'Happiness Rank', 'Country or region': 'Country', 'Score': 'Happiness Score',
                                   'GDP per capita': 'Economy (GDP per Capita)', 'Social support': 'Family (Social Support)',
                                   'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 
                                   'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)', 'Perceptions of corruption'
                                   : 'Trust (Government Corruption)'})

# %%
# Check that the columns were renamed
df_2018.head()
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.632
# 1               2       Norway  Western Europe            7.594
# 2               3      Denmark  Western Europe            7.555
# 3               4      Iceland  Western Europe            7.495
# 4               5  Switzerland  Western Europe            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# 4                     0.927                   0.660
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)
# 0                              0.202                          0.393
# 1                              0.286                          0.340
# 2                              0.284                          0.408
# 3                              0.353                          0.138
# 4                              0.256                          0.357

# %%
# Create a new column called Year to specify the year
df_2018['Year'] = 2018

# %%
df_2018.head()
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.632
# 1               2       Norway  Western Europe            7.594
# 2               3      Denmark  Western Europe            7.555
# 3               4      Iceland  Western Europe            7.495
# 4               5  Switzerland  Western Europe            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# 4                     0.927                   0.660
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)  Year
# 0                              0.202                          0.393  2018
# 1                              0.286                          0.340  2018
# 2                              0.284                          0.408  2018
# 3                              0.353                          0.138  2018
# 4                              0.256                          0.357  2018

# %%
# Create a column called Dystopia Residual which is the Happiness Score subtracting the six columns after it
df_2018['Dystopia Residual'] = df_2018['Happiness Score'] - df_2018.iloc[:, 5:10].sum(axis=1)

# %%
# Reorder the order of the columns so it's consistent with the previous datasets
df_2018 = df_2018.reindex(columns = ['Country', 'Region', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
                                    'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',
                                    'Dystopia Residual'])

# %%
# Check that the columns were reordered
df_2018.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0      Finland  Western Europe  2018               1            7.632
# 1       Norway  Western Europe  2018               2            7.594
# 2      Denmark  Western Europe  2018               3            7.555
# 3      Iceland  Western Europe  2018               4            7.495
# 4  Switzerland  Western Europe  2018               5            7.487
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.305                    1.592
# 1                     1.456                    1.582
# 2                     1.351                    1.590
# 3                     1.343                    1.644
# 4                     1.420                    1.549
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.874                   0.681
# 1                     0.861                   0.686
# 2                     0.868                   0.683
# 3                     0.914                   0.677
# 4                     0.927                   0.660
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                          0.393                              0.202
# 1                          0.340                              0.286
# 2                          0.408                              0.284
# 3                          0.138                              0.353
# 4                          0.357                              0.256
#
#    Dystopia Residual
# 0              3.890
# 1              3.839
# 2              3.722
# 3              3.769
# 4              3.738

# %%
# Check for any outliers or irregular values within the descriptive statistics
df_2018.describe()
# Out:
#          Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   156.0      156.000000       156.000000                156.000000
# mean   2018.0       78.500000         5.375917                  0.891449
# std       0.0       45.177428         1.119506                  0.391921
# min    2018.0        1.000000         2.905000                  0.000000
# 25%    2018.0       39.750000         4.453750                  0.616250
# 50%    2018.0       78.500000         5.378000                  0.949500
# 75%    2018.0      117.250000         6.168500                  1.197750
# max    2018.0      156.000000         7.632000                  2.096000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               156.000000                156.000000
# mean                  1.213237                  0.597346
# std                   0.302372                  0.247579
# min                   0.000000                  0.000000
# 25%                   1.066750                  0.422250
# 50%                   1.255000                  0.644000
# 75%                   1.463000                  0.777250
# max                   1.644000                  1.030000
#
#        Freedom (Life Choices)  Trust (Government Corruption)  \
# count              156.000000                     155.000000
# mean                 0.454506                       0.112000
# std                  0.162424                       0.096492
# min                  0.000000                       0.000000
# 25%                  0.356000                       0.051000
# 50%                  0.487000                       0.082000
# 75%                  0.578500                       0.137000
# max                  0.724000                       0.457000
#
#        Generosity (Donations to Charity)  Dystopia Residual
# count                         156.000000         156.000000
# mean                            0.181006           2.818538
# std                             0.098471           0.658747
# min                             0.000000           0.832000
# 25%                             0.109500           2.354500
# 50%                             0.174000           2.881500
# 75%                             0.239000           3.288000
# max                             0.598000           4.858000

# %% [markdown]
# ## 2019 - World Happiness Report

# %%
df_2019.head()
# Out:
#    Overall rank Country or region          Region  Score  GDP per capita  \
# 0             1           Finland  Western Europe  7.769           1.340
# 1             2           Denmark  Western Europe  7.600           1.383
# 2             3            Norway  Western Europe  7.554           1.488
# 3             4           Iceland  Western Europe  7.494           1.380
# 4             5       Netherlands  Western Europe  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions of corruption
# 0       0.153                      0.393
# 1       0.252                      0.410
# 2       0.271                      0.341
# 3       0.354                      0.118
# 4       0.322                      0.298

# %%
# Rename various columns to conform to the previous data set's naming conventions
df_2019 = df_2019.rename(columns = {'Overall rank': 'Happiness Rank', 'Country or region': 'Country', 'Score': 'Happiness Score',
                                   'GDP per capita': 'Economy (GDP per Capita)', 'Social support': 'Family (Social Support)',
                                   'Healthy life expectancy': 'Health (Life Expectancy)', 'Freedom to make life choices': 
                                   'Freedom (Life Choices)', 'Generosity': 'Generosity (Donations to Charity)', 'Perceptions of corruption'
                                   : 'Trust (Government Corruption)'})

# %%
# Check that the columns were renamed
df_2019.head()
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.769
# 1               2      Denmark  Western Europe            7.600
# 2               3       Norway  Western Europe            7.554
# 3               4      Iceland  Western Europe            7.494
# 4               5  Netherlands  Western Europe            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.340                    1.587
# 1                     1.383                    1.573
# 2                     1.488                    1.582
# 3                     1.380                    1.624
# 4                     1.396                    1.522
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.986                   0.596
# 1                     0.996                   0.592
# 2                     1.028                   0.603
# 3                     1.026                   0.591
# 4                     0.999                   0.557
#
#    Generosity (Donations to Charity)  Trust (Government Corruption)
# 0                              0.153                          0.393
# 1                              0.252                          0.410
# 2                              0.271                          0.341
# 3                              0.354                          0.118
# 4                              0.322                          0.298

# %%
df_2019['Year'] = 2019

# %%
# Create a column called Dystopia Residual which is the Happiness Score subtracting the six columns after it
df_2019['Dystopia Residual'] = df_2019['Happiness Score'] - df_2019.iloc[:, 5:10].sum(axis=1)

# %%
# Reorder the order of the columns so it's consistent with the previous datasets
df_2019 = df_2019.reindex(columns = ['Country', 'Region', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
                                    'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',
                                    'Dystopia Residual'])

# %%
# Check that the columns were reordered
df_2019.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0      Finland  Western Europe  2019               1            7.769
# 1      Denmark  Western Europe  2019               2            7.600
# 2       Norway  Western Europe  2019               3            7.554
# 3      Iceland  Western Europe  2019               4            7.494
# 4  Netherlands  Western Europe  2019               5            7.488
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                     1.340                    1.587
# 1                     1.383                    1.573
# 2                     1.488                    1.582
# 3                     1.380                    1.624
# 4                     1.396                    1.522
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                     0.986                   0.596
# 1                     0.996                   0.592
# 2                     1.028                   0.603
# 3                     1.026                   0.591
# 4                     0.999                   0.557
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                          0.393                              0.153
# 1                          0.410                              0.252
# 2                          0.341                              0.271
# 3                          0.118                              0.354
# 4                          0.298                              0.322
#
#    Dystopia Residual
# 0              4.054
# 1              3.777
# 2              3.729
# 3              3.781
# 4              3.790

# %%
# Check for any outliers or irregular values within the descriptive statistics
df_2019.describe()
# Out:
#          Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count   156.0      156.000000       156.000000                156.000000
# mean   2019.0       78.500000         5.407096                  0.905147
# std       0.0       45.177428         1.113120                  0.398389
# min    2019.0        1.000000         2.853000                  0.000000
# 25%    2019.0       39.750000         4.544500                  0.602750
# 50%    2019.0       78.500000         5.379500                  0.960000
# 75%    2019.0      117.250000         6.184500                  1.232500
# max    2019.0      156.000000         7.769000                  1.684000
#
#        Family (Social Support)  Health (Life Expectancy)  \
# count               156.000000                156.000000
# mean                  1.208814                  0.725244
# std                   0.299191                  0.242124
# min                   0.000000                  0.000000
# 25%                   1.055750                  0.547750
# 50%                   1.271500                  0.789000
# 75%                   1.452500                  0.881750
# max                   1.624000                  1.141000
#
#        Freedom (Life Choices)  Trust (Government Corruption)  \
# count              156.000000                     156.000000
# mean                 0.392571                       0.110603
# std                  0.143289                       0.094538
# min                  0.000000                       0.000000
# 25%                  0.308000                       0.047000
# 50%                  0.417000                       0.085500
# 75%                  0.507250                       0.141250
# max                  0.631000                       0.453000
#
#        Generosity (Donations to Charity)  Dystopia Residual
# count                         156.000000         156.000000
# mean                            0.184846           2.785019
# std                             0.095254           0.651300
# min                             0.000000           0.826000
# 25%                             0.108750           2.326500
# 50%                             0.177500           2.837500
# 75%                             0.248250           3.272500
# max                             0.566000           4.054000

# %% [markdown]
# # 04. Merge the wrangled datasets together

# %%
# Concat the five datasets together since they have the same number of columns
df_years = (df_2015, df_2016, df_2017, df_2018, df_2019)

# %%
df_merged = pd.concat(df_years)

# %%
df_merged.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# 4                   0.90563                 0.63297
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.41978                            0.29678
# 1                        0.14145                            0.43630
# 2                        0.48357                            0.34139
# 3                        0.36503                            0.34699
# 4                        0.32957                            0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
df_merged.shape
# Out:
# (782, 12)

# %% [markdown]
# #### Although data wrangling was performed earlier, I am performing an additional step which is easier once the datasets are merged.

# %% [markdown]
# ### 4.1 Additional data wrangling

# %%
# Create a column called 'Continent' based on the 'Region column
df_merged['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 196
# Central and Eastern Europe         144
# Latin America and Caribbean        111
# Western Europe                     104
# Middle East and Northern Africa     98
# Southeastern Asia                   44
# Southern Asia                       35
# Eastern Asia                        30
# North America                       10
# Australia and New Zealand           10
# Name: Region, dtype: int64

# %%
# Create lists for each continent based on the regions
North_America = ['North America']
South_America = ['Latin America and Caribbean']
Europe = ['Central and Eastern Europe', 'Western Europe']
Asia = ['Southeastern Asia', 'Southern Asia', 'Eastern Asia']
Africa = ['Sub-Saharan Africa', 'Middle East and Northern Africa']
Australia = ['Australia and New Zealand']

# %%
df_merged.loc[df_merged['Region'].isin(North_America), 'Continent'] = 'North America'
df_merged.loc[df_merged['Region'].isin(South_America), 'Continent'] = 'South America'
df_merged.loc[df_merged['Region'].isin(Europe), 'Continent'] = 'Europe'
df_merged.loc[df_merged['Region'].isin(Asia), 'Continent'] = 'Asia'
df_merged.loc[df_merged['Region'].isin(Africa), 'Continent'] = 'Africa'
df_merged.loc[df_merged['Region'].isin(Australia), 'Continent'] = 'Australia'

# %%
df_merged.head()
# Out:
#        Country          Region  Year  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# 4                   0.90563                 0.63297
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.41978                            0.29678
# 1                        0.14145                            0.43630
# 2                        0.48357                            0.34139
# 3                        0.36503                            0.34699
# 4                        0.32957                            0.45811
#
#    Dystopia Residual      Continent
# 0            2.51738         Europe
# 1            2.70201         Europe
# 2            2.49204         Europe
# 3            2.46531         Europe
# 4            2.45176  North America

# %%
# Reorder the columns for consistency
df_merged = df_merged.reindex(columns = ['Country', 'Region', 'Continent', 'Year', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family (Social Support)',
                                    'Health (Life Expectancy)', 'Freedom (Life Choices)', 'Trust (Government Corruption)', 'Generosity (Donations to Charity)',
                                    'Dystopia Residual'])

# %%
df_merged.head()
# Out:
#        Country          Region      Continent  Year  Happiness Rank  \
# 0  Switzerland  Western Europe         Europe  2015               1
# 1      Iceland  Western Europe         Europe  2015               2
# 2      Denmark  Western Europe         Europe  2015               3
# 3       Norway  Western Europe         Europe  2015               4
# 4       Canada   North America  North America  2015               5
#
#    Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 0            7.587                   1.39651                  1.34951
# 1            7.561                   1.30232                  1.40223
# 2            7.527                   1.32548                  1.36058
# 3            7.522                   1.45900                  1.33095
# 4            7.427                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom (Life Choices)  \
# 0                   0.94143                 0.66557
# 1                   0.94784                 0.62877
# 2                   0.87464                 0.64938
# 3                   0.88521                 0.66973
# 4                   0.90563                 0.63297
#
#    Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 0                        0.41978                            0.29678
# 1                        0.14145                            0.43630
# 2                        0.48357                            0.34139
# 3                        0.36503                            0.34699
# 4                        0.32957                            0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %% [markdown]
# # 05. Data consistency checks

# %% [markdown]
# ### 5.1 Missing Values

# %%
# Check for missing values
df_merged.isnull().sum()
# Out:
# Country                              0
# Region                               0
# Continent                            0
# Year                                 0
# Happiness Rank                       0
# Happiness Score                      0
# Economy (GDP per Capita)             0
# Family (Social Support)              0
# Health (Life Expectancy)             0
# Freedom (Life Choices)               0
# Trust (Government Corruption)        1
# Generosity (Donations to Charity)    0
# Dystopia Residual                    0
# dtype: int64

# %%
# Create a dataframe to hold the missing values
df_missing = df_merged[df_merged['Trust (Government Corruption)'].isnull()==True]

# %%
df_missing
# Out:
#                  Country                           Region Continent  Year  \
# 19  United Arab Emirates  Middle East and Northern Africa    Africa  2018
#
#     Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 19              20            6.774                     2.096
#
#     Family (Social Support)  Health (Life Expectancy)  Freedom (Life Choices)  \
# 19                    0.776                      0.67                   0.284
#
#     Trust (Government Corruption)  Generosity (Donations to Charity)  \
# 19                            NaN                              0.186
#
#     Dystopia Residual
# 19              4.858

# %%
# Check the number of rows and columns before dropping the missing value
df_merged.shape
# Out:
# (782, 13)

# %%
# Drop all missing values
df_merged.dropna(inplace = True)

# %%
# Check that there's one less row
df_merged.shape
# Out:
# (781, 13)

# %% [markdown]
# ### 5.2 Duplicates

# %%
# Check for duplicates
df_dup = df_merged[df_merged.duplicated()]

# %%
df_dup
# Out:
# Empty DataFrame
# Columns: [Country, Region, Continent, Year, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family (Social Support), Health (Life Expectancy), Freedom (Life Choices), Trust (Government Corruption), Generosity (Donations to Charity), Dystopia Residual]
# Index: []

# %% [markdown]
# ### 5.3 Mixed-type data

# %%
# Check for mixed-type data
for col in df_merged.columns.tolist():
  weird = (df_merged[[col]].applymap(type) != df_merged[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_merged[weird]) > 0:
    print (col)

# %% [markdown]
# # 06. Export dataset

# %%
df_merged.to_csv(os.path.join (path, '02. Data', 'Prepared Data', 'cleaned_data.csv'))
